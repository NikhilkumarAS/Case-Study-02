# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Vimal\Desktop\DAS\week6\StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
#  No null values in the dataset

# %% [markdown]
# # 1. Find out how many males and females participated in the test

# %%
df.groupby("gender").size().reset_index(name="count")
# Out:
#    gender  count
# 0  female    518
# 1    male    482

# %% [markdown]
#  Participent Male = 482 , Female = 518

# %% [markdown]
# # 2. What do you think about the students' parental level of education?

# %%
pl=df.groupby("parental level of education").size().reset_index(name="count").sort_values('count', ascending=False)
pl
# Out:
#   parental level of education  count
# 4                some college    226
# 0          associate's degree    222
# 2                 high school    196
# 5            some high school    179
# 1           bachelor's degree    118
# 3             master's degree     59

# %%
plt.figure(figsize =(10, 12))
plt.pie(pl["count"], labels = pl["parental level of education"],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# 22.6% students parents are went to some colleges almost same number of parents has associate degree. Only 5.90% students
# parents has masters degree and a small pool of parents has bachelors degree ie 11.80%

# %%
df.groupby("parental level of education").describe()
# Out:
#                             math score                                     \
#                                  count       mean        std   min    25%
# parental level of education
# associate's degree               222.0  67.977477  15.108190  26.0  57.00
# bachelor's degree                118.0  69.288136  15.164117  29.0  61.00
# high school                      196.0  61.821429  15.160466   8.0  53.75
# master's degree                   59.0  70.254237  14.843544  40.0  57.00
# some college                     226.0  67.128319  14.871790  11.0  59.00
# some high school                 179.0  63.134078  16.602894   0.0  53.00
#
#                                                reading score             ...  \
#                               50%   75%    max         count       mean  ...
# parental level of education                                              ...
# associate's degree           67.0  80.0  100.0         222.0  71.018018  ...
# ...

# %%
df.groupby("parental level of education").mean()
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            67.977477      71.018018      70.031532
# bachelor's degree             69.288136      73.000000      73.381356
# high school                   61.821429      64.602041      62.403061
# master's degree               70.254237      75.949153      75.677966
# some college                  67.128319      69.566372      69.035398
# some high school              63.134078      66.759777      64.888268

# %%
df.groupby("parental level of education").std()
# Out:
#                              math score  reading score  writing score
# parental level of education
# associate's degree            15.108190      13.842999      14.260787
# bachelor's degree             15.164117      14.285250      14.728262
# high school                   15.160466      14.245280      14.165172
# master's degree               14.843544      13.046896      13.730711
# some college                  14.871790      14.312932      15.089911
# some high school              16.602894      15.710633      15.736197

# %%
df.groupby("parental level of education").mean().sort_values('math score', ascending=False)
# Out:
#                              math score  reading score  writing score
# parental level of education
# master's degree               70.254237      75.949153      75.677966
# bachelor's degree             69.288136      73.000000      73.381356
# associate's degree            67.977477      71.018018      70.031532
# some college                  67.128319      69.566372      69.035398
# some high school              63.134078      66.759777      64.888268
# high school                   61.821429      64.602041      62.403061

# %% [markdown]
#  Based on mean and standard deviation we can say that students whose parents with master's degree score more marks than
#  other student in all three category . Next best group of students are with parent level of esucation is bachelor's degree and so on. Based on data we can make an assumption that parent level of education has an influvence in students study and their test score.

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on

# %% [markdown]
# #    ● Gender

# %%
df.groupby("gender").describe()
# Out:
#        math score                                                       \
#             count       mean        std   min   25%   50%   75%    max
# gender
# female      518.0  63.376448  16.029928   0.0  54.0  65.0  74.0  100.0
# male        482.0  68.821577  14.556411  27.0  59.0  69.0  79.0  100.0
#
#        reading score             ...              writing score             \
#                count       mean  ...   75%    max         count       mean
# gender                           ...
# female         518.0  72.590734  ...  83.0  100.0         518.0  72.467181
# male           482.0  65.545643  ...  76.0  100.0         482.0  63.446058
#
#
#               std   min   25%   50%   75%    max
# gender
# female  14.844842  10.0  64.0  74.0  82.0  100.0
# male    14.227225  15.0  53.0  64.0  74.0  100.0
#
# [2 rows x 24 columns]

# %%
df.groupby("gender").mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %%
df.groupby("gender").std()
# Out:
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %% [markdown]
# Average score of female students in reading and writing are higher than male students. In mathes male students average
# score is higher than that of female students also standard devition shows that male students marke are mauch more evenly
# spread

# %% [markdown]
# #    ● Test preparation course

# %%
df.groupby("test preparation course").describe()
# Out:
#                         math score                                         \
#                              count      mean        std   min   25%   50%
# test preparation course
# completed                    358.0  69.96648  14.521847  23.0  61.0  70.0
# none                         642.0  63.78972  15.705689   0.0  54.0  64.0
#
#                                      reading score             ...        \
#                           75%    max         count       mean  ...   75%
# test preparation course                                        ...
# completed                79.0  100.0         358.0  74.175978  ...  84.0
# none                     74.0  100.0         642.0  66.417445  ...  76.0
#
#                                writing score                              \
#                            max         count       mean        std   min
# test preparation course
# completed                100.0         358.0  74.684358  13.236412  36.0
# ...

# %%
df.groupby("test preparation course").mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %%
df.groupby("test preparation course").std()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %% [markdown]
# Based on data we can say that students completed the test preparation course score more in all subject and are more evenly
# spread

# %% [markdown]
# # 4. What do you think about the scoring variation for math, reading and writing Based on

# %% [markdown]
# # ● Gender

# %%
df.groupby("gender").describe()
# Out:
#        math score                                                       \
#             count       mean        std   min   25%   50%   75%    max
# gender
# female      518.0  63.376448  16.029928   0.0  54.0  65.0  74.0  100.0
# male        482.0  68.821577  14.556411  27.0  59.0  69.0  79.0  100.0
#
#        reading score             ...              writing score             \
#                count       mean  ...   75%    max         count       mean
# gender                           ...
# female         518.0  72.590734  ...  83.0  100.0         518.0  72.467181
# male           482.0  65.545643  ...  76.0  100.0         482.0  63.446058
#
#
#               std   min   25%   50%   75%    max
# gender
# female  14.844842  10.0  64.0  74.0  82.0  100.0
# male    14.227225  15.0  53.0  64.0  74.0  100.0
#
# [2 rows x 24 columns]

# %%
df.groupby("gender").std()
# Out:
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %% [markdown]
# Based on data, standard deviation of male students scores for all subject are less than that of female students
# which shows that male students scores are much more evenly spread than that of female students.

# %% [markdown]
# # ● Test preparation course

# %%
df.groupby("test preparation course").describe()
# Out:
#                         math score                                         \
#                              count      mean        std   min   25%   50%
# test preparation course
# completed                    358.0  69.96648  14.521847  23.0  61.0  70.0
# none                         642.0  63.78972  15.705689   0.0  54.0  64.0
#
#                                      reading score             ...        \
#                           75%    max         count       mean  ...   75%
# test preparation course                                        ...
# completed                79.0  100.0         358.0  74.175978  ...  84.0
# none                     74.0  100.0         642.0  66.417445  ...  76.0
#
#                                writing score                              \
#                            max         count       mean        std   min
# test preparation course
# completed                100.0         358.0  74.684358  13.236412  36.0
# ...

# %%
df.groupby("test preparation course").std()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %% [markdown]
# Based on the data , standard deviation of scores of students who completed test preparation course are less than that of
# students with no test preparation course's.So we can say that the students who completed test preparation course have score
# much more evenly spread than that of students with no test preparation course

# %% [markdown]
# # 5.Top 25% students based on their maths score

# %%
df["gender"].count()
# Out:
# 1000

# %% [markdown]
# There are total of 1000 students. 25% of 1000 = 250

# %%
sr=df.sort_values(["math score","reading score","writing score"], ascending=False)
sr
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 51   female        group C            some high school  free/reduced
# 3    female        group B                some college      standard
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Sorted the data set based on math score. Too many people have same score in maths so additional sorting applind in both
# reading and writing coloum. So if any selection problem occure that is same value it reffer other coloum value and sort
# accordingly.

# %%
sr.head(250)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 853    male        group D          associate's degree  free/reduced
# 427  female        group D          associate's degree      standard
# 856    male        group E            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 426  female        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# These are the top 25% of people score more mark in maths.

# %% [markdown]
# #    Using quantile

# %%
qt=df.sort_values(["math score"], ascending=True)
qt.head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C            some high school  free/reduced
# 1   female        group B                 high school  free/reduced
# 3   female        group B                some college      standard
# 51  female        group C            some high school  free/reduced
# 2   female        group B            some high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none           0             17             10
# 1                     none           8             24             23
# 3                     none          11             38             32
# 51                    none          13             41             51
# 2                     none          18             32             28

# %%
qt["math score"].quantile(.75)
# Out:
# 77.0

# %% [markdown]
# Using quantile function we can say that top 25% sudent in mathes  score 77 or more in the test

# %%
qu=df[df["math score"]>=77].sort_values("math score", ascending=False)
qu
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# 996    male        group A                some college      standard
# 517  female        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 854    male        group D            some high school      standard
# 855    male        group E          associate's degree  free/reduced
# 856    male        group E            some high school      standard
# 415  female        group B             master's degree  free/reduced
# 414  female        group A                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
qu["gender"].count()
# Out:
# 255

# %% [markdown]
#  Threre are total of 255 students who score 77 or more  in mathes. they are the top 25% student in mathes
